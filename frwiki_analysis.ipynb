# %%
import numpy as np
import pandas as pd

# %%
# read in headers file by chunks of 100000 to conserve memory
# https://stackoverflow.com/questions/25962114/how-to-read-a-6-gb-csv-file-with-pandas
tp = pd.read_csv('frwiki_20161001_headings_3.tsv', sep='\t', header=0, dtype={'page_id': np.int32, 'page_title': object, 'page_ns': np.int16, 'heading_level': np.int8, 'heading_text': object}, iterator=True, chunksize=100000)

# %%
# concatenate all rows where page_ns is equal to zero (article namespace) into a pandas dataframe
fr_DF = pd.concat([chunk[chunk['page_ns'] == 0] for chunk in tp])

# %%
fr_DF.head()
# Out:
#    page_id          page_title  page_ns  heading_level       heading_text
# 0   412304  Dragon Head (film)        0              2          Synopsis
# 1   412304  Dragon Head (film)        0              2   Fiche technique
# 2   412304  Dragon Head (film)        0              2       Distribution
# 3   412304  Dragon Head (film)        0              2      Distinctions
# 4   412304  Dragon Head (film)        0              2        Voir aussi

# %%
fr_DF.page_ns.unique()
# Out:
# array([0])

# %%
# determine number of unique articles
len(fr_DF['page_title'].unique())
# Out:
# 1651669

# %%
# remove leading and trailing whitespace from heading_text column
fr_DF['heading_text'] = pd.core.strings.str_strip(fr_DF['heading_text'])

# %%
# groupby heading_text and count the number of unique page_titles each heading appears in
# sort in descencing order
# this returns a pandas series object
article_count = fr_DF.groupby('heading_text')['page_title'].apply(lambda x: len(x.unique())).sort_values(ascending=False)

# %%
# turn pandas series object into pandas dataframe
fr_article_count_DF = pd.DataFrame({'section_title':article_count.index, 'number_of_articles':article_count.values})

# %%
# add a column for the percentage of articles that header appears in
fr_article_count_DF['article_percentage'] = (fr_article_count_DF['number_of_articles']/1651669)*100

# %%
# set pandas options to display 100 rows
# round percentage to 2 decimal places and show top 100 results
pd.options.display.max_rows = 100
fr_article_count_DF.round({'article_percentage': 2}).head(100)
# Out:
#     number_of_articles                     section_title  article_percentage
# 0               784431               Notes et références               47.49
# 1               726584                    Liens externes               43.99
# 2               425307                        Voir aussi               25.75
# 3               333309                        Références               20.18
# 4               326686                 Articles connexes               19.78
# 5               286614                        Biographie               17.35
# 6               230732                          Histoire               13.97
# 7               228681                     Bibliographie               13.85
# 8               152555                      Lien externe                9.24
# 9               119083                        Géographie                7.21
# 10              102366                             Notes                6.20
# 11              101336                           Annexes                6.14
# 12               97101                          Palmarès                5.88
# 13               85245                       Description                5.16
# 14               84933                        Historique                5.14
# 15               80406                       Démographie                4.87
# 16               80307                      Distribution                4.86
# 17               79410                           Sources                4.81
# 18               65404                          Synopsis                3.96
# 19               53854                   Fiche technique                3.26
# 20               46681                          Carrière                2.83
# 21               46060                      Filmographie                2.79
# 22               42774                   Article connexe                2.59
# 23               40178                    Liens internes                2.43
# 24               39710                          Économie                2.40
# 25               37169       Politique et administration                2.25
# 26               37001                Lieux et monuments                2.24
# 27               36238             Publication originale                2.19
# 28               35172  Personnalités liées à la commune                2.13
# 29               35158                         Toponymie                2.13
# 30               33592                            Source                2.03
# 31               30977                            Œuvres                1.88
# 32               28739                      Discographie                1.74
# 33               25583                       Répartition                1.55
# 34               24408                    Administration                1.48
# 35               22915              Communes limitrophes                1.39
# 36               22128                        Étymologie                1.34
# 37               21250                      Localisation                1.29
# 38               20961                      Statistiques                1.27
# 39               20074                       Compléments                1.22
# 40               19925                      Distinctions                1.21
# 41               19851                      Publications                1.20
# 42               18424                            Cinéma                1.12
# 43               18086                       Récompenses                1.10
# 44               17309                           Galerie                1.05
# 45               16380                        Événements                0.99
# 46               16104                        Héraldique                0.98
# 47               16007                        Télévision                0.97
# 48               15802                         Résultats                0.96
# 49               15133                       Composition                0.92
# 50               14473                            Résumé                0.88
# 51               14154                      Présentation                0.86
# 52               13276                  Caractéristiques                0.80
# 53               13133                             Décès                0.80
# 54               12562      Culture locale et patrimoine                0.76
# 55               11944                  Liste des titres                0.72
# 56               11764                  Liste des maires                0.71
# 57               11721                        Classement                0.71
# 58               11528           Source de la traduction                0.70
# 59               11512                           Culture                0.70
# 60               11118                        Naissances                0.67
# 61               10889                         Situation                0.66
# 62               10591                           Accueil                0.64
# 63               10369                      Architecture                0.63
# 64               10193                         Patronyme                0.62
# 65               10188                 Liste des espèces                0.62
# 66               10170                         Référence                0.62
# 67               10130             Population et société                0.61
# 68                9855                             Œuvre                0.60
# 69                9773                           En club                0.59
# 70                9660                          Parcours                0.58
# 71                9528                           Théâtre                0.58
# 72                9450                        Production                0.57
# 73                9333                         Jumelages                0.57
# 74                9208                    Autour du film                0.56
# 75                9207                            Autres                0.56
# 76                9027                            Climat                0.55
# 77                9001                          Contexte                0.54
# 78                8877                  Pour approfondir                0.54
# 79                8834                       Personnages                0.53
# 80                8478                     Personnalités                0.51
# 81                8466                      Hydrographie                0.51
# 82                8365                      Enseignement                0.51
# 83                8359                        Vie privée                0.51
# 84                8342                            Albums                0.51
# 85                8196           Références taxinomiques                0.50
# 86                8149           Évolution démographique                0.49
# 87                8064                            Titres                0.49
# 88                7907                           Musique                0.48
# 89                7871                       Compétition                0.48
# 90                7839        [[Hameau italien|Hameaux]]                0.47
# 91                7717                        Population                0.47
# 92                7500                           Records                0.45
# 93                7396                      Organisation                0.45
# 94                7262                       Nominations                0.44
# 95                7260                    Système de jeu                0.44
# 96                7089                          Ouvrages                0.43
# 97                7081                           Famille                0.43
# 98                7071                           Origine                0.43
# 99                7007                          Toponyme                0.42
