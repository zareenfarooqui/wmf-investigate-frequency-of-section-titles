# %%
import numpy as np
import pandas as pd

# %%
# read in headers file by chunks of 100000 to conserve memory
# https://stackoverflow.com/questions/25962114/how-to-read-a-6-gb-csv-file-with-pandas
tp = pd.read_csv('dewiki_20161001_headings_4.tsv', sep='\t', header=0, dtype={'page_id': np.int32, 'page_title': object, 'page_ns': np.int16, 'heading_level': np.int8, 'heading_text': object}, iterator=True, chunksize=100000)

# %%
# concatenate all rows where page_ns is equal to zero (article namespace) into a pandas dataframe
de_DF = pd.concat([chunk[chunk['page_ns'] == 0] for chunk in tp])

# %%
de_DF.head()
# Out:
#    page_id                 page_title  page_ns  heading_level  \
# 0  4964505  Zentralschweizer Voralpen        0              2
# 1  4964505  Zentralschweizer Voralpen        0              2
# 2  4964532               Mario Terzic        0              2
# 3  4964532               Mario Terzic        0              2
# 4  1877065        Ndebele (Südafrika)        0              2
#
#                     heading_text
# 0                     Literatur
# 1               Einzelnachweise
# 2                Leben und Werk
# 3                 Lehrtätigkeit
# 4   Beschreibung und Geschichte

# %%
de_DF.page_ns.unique()
# Out:
# array([0])

# %%
# determine number of unique articles
len(de_DF['page_title'].unique())
# Out:
# 1714070

# %%
# remove leading and trailing whitespace from heading_text column
de_DF['heading_text'] = pd.core.strings.str_strip(de_DF['heading_text'])

# %%
# groupby heading_text and count the number of unique page_titles each heading appears in
# sort in descencing order
# this returns a pandas series object
article_count = de_DF.groupby('heading_text')['page_title'].apply(lambda x: len(x.unique())).sort_values(ascending=False)

# %%
# turn pandas series object into pandas dataframe
de_article_count_DF = pd.DataFrame({'section_title':article_count.index, 'number_of_articles':article_count.values})

# %%
# add a column for the percentage of articles that header appears in
de_article_count_DF['article_percentage'] = (de_article_count_DF['number_of_articles']/1714070)*100

# %%
# set pandas options to display 100 rows
# round percentage to 2 decimal places and show top 100 results
pd.options.display.max_rows = 100
de_article_count_DF.round({'article_percentage': 2}).head(100)
# Out:
#     number_of_articles                  section_title  article_percentage
# 0              1259258                       Weblinks               73.47
# 1               920950                Einzelnachweise               53.73
# 2               558809                      Literatur               32.60
# 3               295785                     Geschichte               17.26
# 4               258960                          Leben               15.11
# 5               181868                     Siehe auch               10.61
# 6                77943                        Quellen                4.55
# 7                59267                 Auszeichnungen                3.46
# 8                58009                       Karriere                3.38
# 9                56781                     Geographie                3.31
# 10               52200                          Werke                3.05
# 11               41570             Sehenswürdigkeiten                2.43
# 12               39690                       Handlung                2.32
# 13               37189                   Beschreibung                2.17
# 14               32705                      Geografie                1.91
# 15               32597                        Erfolge                1.90
# 16               32431                      Werdegang                1.89
# 17               31567                        Verkehr                1.84
# 18               30740                        Politik                1.79
# 19               30223                           Lage                1.76
# 20               29444                    Anmerkungen                1.72
# 21               29246                      Schriften                1.71
# 22               26783                    Diskografie                1.56
# 23               25313          Filmografie (Auswahl)                1.48
# 24               25253               Leben und Wirken                1.47
# 25               24722               Persönlichkeiten                1.44
# 26               22638        Bevölkerungsentwicklung                1.32
# 27               22234                       Ehrungen                1.30
# 28               22022                       Merkmale                1.28
# 29               20913                    Hintergrund                1.22
# 30               19549                      Sonstiges                1.14
# 31               18930                      Biografie                1.10
# 32               18528                Werke (Auswahl)                1.08
# 33               18259                         Kritik                1.07
# 34               17734                         Wappen                1.03
# 35               17617                       Fußnoten                1.03
# 36               17611                    Filmografie                1.03
# 37               17368                     Wirtschaft                1.01
# 38               17261                      Rezeption                1.01
# 39               16465                    Bevölkerung                0.96
# 40               16039                        Familie                0.94
# 41               15975                         Belege                0.93
# 42               15335   Wirtschaft und Infrastruktur                0.89
# 43               15323             Veröffentlichungen                0.89
# 44               14606                       Kritiken                0.85
# 45               14201  Kultur und Sehenswürdigkeiten                0.83
# 46               13687                 Leben und Werk                0.80
# 47               13397                     Systematik                0.78
# 48               12998             Nationalmannschaft                0.76
# 49               12879                         Inhalt                0.75
# 50               12470                           Werk                0.73
# 51               11980                    Verbreitung                0.70
# 52               11393            Schriften (Auswahl)                0.66
# 53               11323                     Ergebnisse                0.66
# 54               10725                          Alben                0.63
# 55               10695             Geographische Lage                0.62
# 56               10143                    Lebensweise                0.59
# 57                9992           Einwohnerentwicklung                0.58
# 58                9650                        Verlauf                0.56
# 59                9626                         Quelle                0.56
# 60                9580                     Referenzen                0.56
# 61                9527                        Singles                0.56
# 62                9296    Söhne und Töchter der Stadt                0.54
# 63                9261                     Verwendung                0.54
# 64                9137                      Vorkommen                0.53
# 65                9049                        Weblink                0.53
# 66                9029                         Trivia                0.53
# 67                8828                  Eigenschaften                0.52
# 68                8757                    Architektur                0.51
# 69                8185             Gemeindegliederung                0.48
# 70                7980                        Bildung                0.47
# 71                7912                      Nachweise                0.46
# 72                7832               Technische Daten                0.46
# 73                7679                          Sport                0.45
# 74                7642                  Publikationen                0.45
# 75                7626     Erfolge und Auszeichnungen                0.44
# 76                7505                     Entstehung                0.44
# 77                7369                    Ausstattung                0.43
# 78                7352                      Statistik                0.43
# 79                7256                  Vorgeschichte                0.42
# 80                7250                        Galerie                0.42
# 81                7197                       Privates                0.42
# 82                7185                       Bauwerke                0.42
# 83                7043                         Finale                0.41
# 84                6863                     Titelliste                0.40
# 85                6837                         Verein                0.40
# 86                6586                          Modus                0.38
# 87                6519                     Produktion                0.38
# 88                6510                  International                0.38
# 89                6478                    Allgemeines                0.38
# 90                6439                      Bedeutung                0.38
# 91                6390                        Vereine                0.37
# 92                6389                       Herkunft                0.37
# 93                6222                      Gemeinden                0.36
# 94                6208          Städtepartnerschaften                0.36
# 95                6054                         Bilder                0.35
# 96                6052             Leben und Karriere                0.35
# 97                5997                         Einzel                0.35
# 98                5974                    Gemeinderat                0.35
# 99                5868                      Setzliste                0.34
